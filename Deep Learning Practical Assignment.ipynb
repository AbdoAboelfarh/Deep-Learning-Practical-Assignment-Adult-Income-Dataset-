# %% [markdown]
# ### Deep Learning Practical Assignment — Adult Income Dataset

# %% [markdown]
# ### Part 0 — Data Preparation

# %% [markdown]
# ### Load dataset, clean (replace '?'), split (70/15/15), preprocess (scale numerics,one-hot encode categoricals)

# %%
import numpy as np, pandas as pd, os, joblib, matplotlib.pyplot as plt, time
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, callbacks

print('Loading Adult dataset from OpenML (this requires internet)...')
adult = fetch_openml(name='adult', version=2, as_frame=True)
df = adult.frame.copy()
print('Raw shape:', df.shape)

# Replace '?' with NaN and drop rows with missing values
df.replace('?', np.nan, inplace=True)
df = df.dropna().reset_index(drop=True)
print('After dropna shape:', df.shape)

# Prepare features and target
X = df.drop(columns='class')
y = df['class'].apply(lambda s: 1 if str(s).strip().startswith('>50K') else 0)

# Train/val/test splits (70% / 15% / 15%)
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, random_state=42, stratify=y
)
relative_val_size = 0.15 / 0.85
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=relative_val_size, random_state=42, stratify=y_temp
)
print('Splits shapes -> train:', X_train.shape, 'val:', X_val.shape, 'test:', X_test.shape)

# Identify column types
numeric_features = X.select_dtypes(include=['int64','float64']).columns.tolist()
categorical_features = X.select_dtypes(include=['object','category']).columns.tolist()
print('Numeric features:', numeric_features)
print('Categorical features count:', len(categorical_features))

# Preprocessor: scale numeric, one-hot categorical
preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numeric_features),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
])

print('Fitting preprocessor on training data...')
preprocessor.fit(X_train)

X_train_p = preprocessor.transform(X_train)
X_val_p   = preprocessor.transform(X_val)
X_test_p  = preprocessor.transform(X_test)

# Ensure float32 dtype for Keras
X_train_p = np.array(X_train_p, dtype=np.float32)
X_val_p   = np.array(X_val_p, dtype=np.float32)
X_test_p  = np.array(X_test_p, dtype=np.float32)

y_train = np.array(y_train, dtype=np.float32)
y_val   = np.array(y_val, dtype=np.float32)
y_test  = np.array(y_test, dtype=np.float32)

print('Preprocessed shapes ->', X_train_p.shape, X_val_p.shape, X_test_p.shape)

# Save preprocessor
os.makedirs('adult_results', exist_ok=True)
joblib.dump(preprocessor, 'adult_results/preprocessor.joblib')
print('Preprocessor saved to adult_results/preprocessor.joblib')
# Out:
# Loading Adult dataset from OpenML (this requires internet)...
# Raw shape: (48842, 15)
# After dropna shape: (45222, 15)
# Splits shapes -> train: (31654, 14) val: (6784, 14) test: (6784, 14)
# Numeric features: ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# Categorical features count: 8
# Fitting preprocessor on training data...
# Preprocessed shapes -> (31654, 104) (6784, 104) (6784, 104)
# Preprocessor saved to adult_results/preprocessor.joblib

# %% [markdown]
# ### Helper: model builder and training function (Keras).

# %%
# Part 1 experiments

# Function to build MLP
def build_mlp(input_dim, hidden_layers=[128,64], l2=0.0, dropout=0.0):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_dim,)))
    for units in hidden_layers:
        model.add(layers.Dense(units, activation='relu',
                               kernel_regularizer=regularizers.l2(l2)))
        if dropout > 0:
            model.add(layers.Dropout(dropout))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# Training function
def train_model(model, optimizer, X_train, y_train, X_val, y_val, 
                X_test=None, y_test=None,
                batch_size=64, epochs=20, verbose=1, use_early_stopping=False):
    
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    cbs = []
    if use_early_stopping:
        cbs.append(callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True))
    
    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=cbs,
                        verbose=verbose)
    
    train_acc = history.history['accuracy'][-1]
    val_acc   = history.history['val_accuracy'][-1]
    test_acc  = None
    if X_test is not None:
        test_acc = model.evaluate(X_test, y_test, verbose=0)[1]
    
    return history, train_acc, val_acc, test_acc


# Experiment settings
input_dim = X_train_p.shape[1]
hidden = [128,64]
epochs = 20
batch_size = 64

results = []
histories = {}

optimizers = {
    'SGD': keras.optimizers.SGD(learning_rate=0.01),
    'SGD_momentum': keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    'Adam': keras.optimizers.Adam(learning_rate=0.001)
}

# Run experiments
for name, opt in optimizers.items():
    print('\nTraining with', name)
    model = build_mlp(input_dim, hidden_layers=hidden, l2=0.0, dropout=0.0)
    hist, tr_acc, val_acc, test_acc = train_model(
        model, optimizer=opt,
        X_train=X_train_p, y_train=y_train,
        X_val=X_val_p, y_val=y_val,
        X_test=X_test_p, y_test=y_test,
        batch_size=batch_size, epochs=epochs, verbose=1
    )
    histories[name] = hist
    results.append({
        'part': 'optimizers',
        'method': name,
        'train_acc': tr_acc,
        'val_acc': val_acc,
        'test_acc': test_acc
    })
    
    # Save accuracy plots
    plt.figure(figsize=(6,4))
    plt.plot(hist.history['accuracy'], label='train acc')
    plt.plot(hist.history['val_accuracy'], label='val acc')
    plt.title(f'{name} — accuracy')
    plt.xlabel('epoch'); plt.ylabel('accuracy'); plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'adult_results/optim_{name}.png')
    plt.close()

# Save results table
pd.DataFrame(results).to_csv('adult_results/part1_optimizers_results.csv', index=False)
print('\nPart1 results saved to adult_results/part1_optimizers_results.csv')

# %% [markdown]
# ## Part 1 — Optimizers
# Train the same model with SGD, SGD+momentum, and Adam. Plot curves and report train/val/test accuracies.

# %%
# Function to build MLP
def build_mlp(input_dim, hidden_layers=[128,64], l2=0.0, dropout=0.0):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_dim,)))
    for units in hidden_layers:
        model.add(layers.Dense(units, activation='relu',
                               kernel_regularizer=regularizers.l2(l2)))
        if dropout > 0:
            model.add(layers.Dropout(dropout))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# Training function
def train_model(model, optimizer, X_train, y_train, X_val, y_val, 
                X_test=None, y_test=None,
                batch_size=64, epochs=20, verbose=1, use_early_stopping=False):
    
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    cbs = []
    if use_early_stopping:
        cbs.append(callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True))
    
    history = model.fit(X_train, y_train,
                        validation_data=(X_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=cbs,
                        verbose=verbose)
    
    train_acc = history.history['accuracy'][-1]
    val_acc   = history.history['val_accuracy'][-1]
    test_acc  = None
    if X_test is not None:
        test_acc = model.evaluate(X_test, y_test, verbose=0)[1]
    
    return history, train_acc, val_acc, test_acc


# Experiment settings
input_dim = X_train_p.shape[1]
hidden = [128,64]
epochs = 20
batch_size = 64

results = []
histories = {}

optimizers = {
    'SGD': keras.optimizers.SGD(learning_rate=0.01),
    'SGD_momentum': keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
    'Adam': keras.optimizers.Adam(learning_rate=0.001)
}

# Run experiments
for name, opt in optimizers.items():
    print('\nTraining with', name)
    model = build_mlp(input_dim, hidden_layers=hidden, l2=0.0, dropout=0.0)
    hist, tr_acc, val_acc, test_acc = train_model(
        model, optimizer=opt,
        X_train=X_train_p, y_train=y_train,
        X_val=X_val_p, y_val=y_val,
        X_test=X_test_p, y_test=y_test,
        batch_size=batch_size, epochs=epochs, verbose=1
    )
    histories[name] = hist
    results.append({
        'part': 'optimizers',
        'method': name,
        'train_acc': tr_acc,
        'val_acc': val_acc,
        'test_acc': test_acc
    })
    
    # Save accuracy plots
    plt.figure(figsize=(6,4))
    plt.plot(hist.history['accuracy'], label='train acc')
    plt.plot(hist.history['val_accuracy'], label='val acc')
    plt.title(f'{name} — accuracy')
    plt.xlabel('epoch'); plt.ylabel('accuracy'); plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'adult_results/optim_{name}.png')
    plt.close()

# Save results table
pd.DataFrame(results).to_csv('adult_results/part1_optimizers_results.csv', index=False)
print('\nPart1 results saved to adult_results/part1_optimizers_results.csv')
# Out:
# Training with SGD
# Epoch 1/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7765 - loss: 0.4527 - val_accuracy: 0.8252 - val_loss: 0.3803
# Epoch 2/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8351 - loss: 0.3603 - val_accuracy: 0.8361 - val_loss: 0.3540
# Epoch 3/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8401 - loss: 0.3441 - val_accuracy: 0.8398 - val_loss: 0.3446
# Epoch 4/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8441 - loss: 0.3356 - val_accuracy: 0.8438 - val_loss: 0.3379
# Epoch 5/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8466 - loss: 0.3298 - val_accuracy: 0.8436 - val_loss: 0.3337
# Epoch 6/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8484 - loss: 0.3257 - val_accuracy: 0.8436 - val_loss: 0.3305
# Epoch 7/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8511 - loss: 0.3227 - val_accuracy: 0.8458 - val_loss: 0.3286
# Epoch 8/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8505 - loss: 0.3204 - val_accuracy: 0.8471 - val_loss: 0.3269
# Epoch 9/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8512 - loss: 0.3188 - val_accuracy: 0.8471 - val_loss: 0.3254
# Epoch 10/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8519 - loss: 0.3174 - val_accuracy: 0.8477 - val_loss: 0.3246
# Epoch 11/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8523 - loss: 0.3163 - val_accuracy: 0.8495 - val_loss: 0.3230
# Epoch 12/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8533 - loss: 0.3155 - val_accuracy: 0.8495 - val_loss: 0.3229
# Epoch 13/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8533 - loss: 0.3146 - val_accuracy: 0.8489 - val_loss: 0.3231
# Epoch 14/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8540 - loss: 0.3141 - val_accuracy: 0.8498 - val_loss: 0.3218
# Epoch 15/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8538 - loss: 0.3135 - val_accuracy: 0.8496 - val_loss: 0.3214
# Epoch 16/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8545 - loss: 0.3130 - val_accuracy: 0.8495 - val_loss: 0.3209
# Epoch 17/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8542 - loss: 0.3126 - val_accuracy: 0.8495 - val_loss: 0.3205
# Epoch 18/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8548 - loss: 0.3121 - val_accuracy: 0.8502 - val_loss: 0.3205
# Epoch 19/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8558 - loss: 0.3116 - val_accuracy: 0.8513 - val_loss: 0.3208
# Epoch 20/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8555 - loss: 0.3114 - val_accuracy: 0.8510 - val_loss: 0.3199
#
# Training with SGD_momentum
# Epoch 1/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8320 - loss: 0.3552 - val_accuracy: 0.8454 - val_loss: 0.3256
# Epoch 2/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8504 - loss: 0.3190 - val_accuracy: 0.8495 - val_loss: 0.3206
# Epoch 3/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8521 - loss: 0.3156 - val_accuracy: 0.8466 - val_loss: 0.3204
# Epoch 4/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8550 - loss: 0.3127 - val_accuracy: 0.8492 - val_loss: 0.3206
# Epoch 5/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8539 - loss: 0.3117 - val_accuracy: 0.8496 - val_loss: 0.3185
# Epoch 6/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8567 - loss: 0.3104 - val_accuracy: 0.8491 - val_loss: 0.3172
# Epoch 7/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8558 - loss: 0.3086 - val_accuracy: 0.8467 - val_loss: 0.3208
# Epoch 8/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8571 - loss: 0.3073 - val_accuracy: 0.8508 - val_loss: 0.3174
# Epoch 9/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8562 - loss: 0.3069 - val_accuracy: 0.8527 - val_loss: 0.3177
# Epoch 10/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8581 - loss: 0.3065 - val_accuracy: 0.8519 - val_loss: 0.3193
# Epoch 11/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8585 - loss: 0.3051 - val_accuracy: 0.8510 - val_loss: 0.3177
# Epoch 12/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8588 - loss: 0.3043 - val_accuracy: 0.8516 - val_loss: 0.3170
# Epoch 13/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8596 - loss: 0.3033 - val_accuracy: 0.8508 - val_loss: 0.3168
# Epoch 14/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8602 - loss: 0.3027 - val_accuracy: 0.8539 - val_loss: 0.3173
# Epoch 15/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8607 - loss: 0.3014 - val_accuracy: 0.8526 - val_loss: 0.3146
# Epoch 16/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8605 - loss: 0.3006 - val_accuracy: 0.8535 - val_loss: 0.3148
# Epoch 17/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8617 - loss: 0.2998 - val_accuracy: 0.8526 - val_loss: 0.3149
# Epoch 18/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8609 - loss: 0.2994 - val_accuracy: 0.8545 - val_loss: 0.3153
# Epoch 19/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8609 - loss: 0.2980 - val_accuracy: 0.8519 - val_loss: 0.3168
# Epoch 20/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8605 - loss: 0.2983 - val_accuracy: 0.8536 - val_loss: 0.3162
#
# Training with Adam
# Epoch 1/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8441 - loss: 0.3338 - val_accuracy: 0.8477 - val_loss: 0.3240
# Epoch 2/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8548 - loss: 0.3133 - val_accuracy: 0.8519 - val_loss: 0.3183
# Epoch 3/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8560 - loss: 0.3085 - val_accuracy: 0.8516 - val_loss: 0.3151
# Epoch 4/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8588 - loss: 0.3053 - val_accuracy: 0.8498 - val_loss: 0.3203
# Epoch 5/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8602 - loss: 0.3022 - val_accuracy: 0.8530 - val_loss: 0.3149
# Epoch 6/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8614 - loss: 0.2977 - val_accuracy: 0.8513 - val_loss: 0.3174
# Epoch 7/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8638 - loss: 0.2949 - val_accuracy: 0.8486 - val_loss: 0.3218
# Epoch 8/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8658 - loss: 0.2911 - val_accuracy: 0.8533 - val_loss: 0.3209
# Epoch 9/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8661 - loss: 0.2879 - val_accuracy: 0.8492 - val_loss: 0.3183
# Epoch 10/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8677 - loss: 0.2845 - val_accuracy: 0.8529 - val_loss: 0.3208
# Epoch 11/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8704 - loss: 0.2807 - val_accuracy: 0.8460 - val_loss: 0.3235
# Epoch 12/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8706 - loss: 0.2776 - val_accuracy: 0.8449 - val_loss: 0.3260
# Epoch 13/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8722 - loss: 0.2736 - val_accuracy: 0.8479 - val_loss: 0.3272
# Epoch 14/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8746 - loss: 0.2700 - val_accuracy: 0.8488 - val_loss: 0.3309
# Epoch 15/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8759 - loss: 0.2666 - val_accuracy: 0.8477 - val_loss: 0.3347
# Epoch 16/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8772 - loss: 0.2636 - val_accuracy: 0.8471 - val_loss: 0.3363
# Epoch 17/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8788 - loss: 0.2608 - val_accuracy: 0.8498 - val_loss: 0.3354
# Epoch 18/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8813 - loss: 0.2570 - val_accuracy: 0.8485 - val_loss: 0.3463
# Epoch 19/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8825 - loss: 0.2548 - val_accuracy: 0.8448 - val_loss: 0.3447
# Epoch 20/20
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8828 - loss: 0.2515 - val_accuracy: 0.8435 - val_loss: 0.3540
#
# Part1 results saved to adult_results/part1_optimizers_results.csv

# %% [markdown]
# ## Part 2 — Batch Size
# Train the model with different batch sizes and record results.

# %%
# Part 2 experiments (use Adam optimizer)
batch_sizes = [1, 32, 128, 1024]
results_bs = []
for bs in batch_sizes:
    print('\nTraining with batch size =', bs)
    model = build_mlp(input_dim, hidden_layers=hidden)
    hist, tr_acc, val_acc, test_acc = train_model(model, optimizer=keras.optimizers.Adam(learning_rate=0.001), X_train=X_train_p, y_train=y_train, X_val=X_val_p, y_val=y_val, batch_size=bs, epochs=12, verbose=1)
    results_bs.append({'part':'batch_size','batch_size':bs,'train_acc':tr_acc,'val_acc':val_acc,'test_acc':test_acc})
    plt.figure(figsize=(6,4))
    plt.plot(hist.history['accuracy'], label='train acc')
    plt.plot(hist.history['val_accuracy'], label='val acc')
    plt.title(f'Batch size {bs} — accuracy'); plt.xlabel('epoch'); plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'/content/adult_results/bs_{bs}_acc.png')
    plt.close()

pd.DataFrame(results_bs).to_csv('/content/adult_results/part2_batchsize_results.csv', index=False)
print('\nPart2 results saved to /content/adult_results/part2_batchsize_results.csv')
# Out:
# Training with batch size = 1
# Epoch 1/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 36s 1ms/step - accuracy: 0.8459 - loss: 0.3313 - val_accuracy: 0.8499 - val_loss: 0.3299
# Epoch 2/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 72s 2ms/step - accuracy: 0.8544 - loss: 0.3192 - val_accuracy: 0.8514 - val_loss: 0.3258
# Epoch 3/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 76s 2ms/step - accuracy: 0.8578 - loss: 0.3174 - val_accuracy: 0.8520 - val_loss: 0.3203
# Epoch 4/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 79s 2ms/step - accuracy: 0.8577 - loss: 0.3126 - val_accuracy: 0.8560 - val_loss: 0.3188
# Epoch 5/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - accuracy: 0.8588 - loss: 0.3098 - val_accuracy: 0.8522 - val_loss: 0.3211
# Epoch 6/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 78s 2ms/step - accuracy: 0.8594 - loss: 0.3085 - val_accuracy: 0.8535 - val_loss: 0.3220
# Epoch 7/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 80s 3ms/step - accuracy: 0.8604 - loss: 0.3073 - val_accuracy: 0.8550 - val_loss: 0.3299
# Epoch 8/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 91s 3ms/step - accuracy: 0.8613 - loss: 0.3042 - val_accuracy: 0.8541 - val_loss: 0.3236
# Epoch 9/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 90s 3ms/step - accuracy: 0.8628 - loss: 0.3034 - val_accuracy: 0.8560 - val_loss: 0.3252
# Epoch 10/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 66s 2ms/step - accuracy: 0.8637 - loss: 0.3006 - val_accuracy: 0.8567 - val_loss: 0.3155
# Epoch 11/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - accuracy: 0.8652 - loss: 0.2988 - val_accuracy: 0.8561 - val_loss: 0.3200
# Epoch 12/12
# 31654/31654 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - accuracy: 0.8648 - loss: 0.2976 - val_accuracy: 0.8523 - val_loss: 0.3286
#
# Training with batch size = 32
# Epoch 1/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8432 - loss: 0.3318 - val_accuracy: 0.8522 - val_loss: 0.3192
# Epoch 2/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8544 - loss: 0.3123 - val_accuracy: 0.8464 - val_loss: 0.3268
# Epoch 3/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8554 - loss: 0.3085 - val_accuracy: 0.8533 - val_loss: 0.3174
# Epoch 4/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8590 - loss: 0.3042 - val_accuracy: 0.8526 - val_loss: 0.3172
# Epoch 5/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8605 - loss: 0.3007 - val_accuracy: 0.8519 - val_loss: 0.3181
# Epoch 6/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8623 - loss: 0.2971 - val_accuracy: 0.8510 - val_loss: 0.3191
# Epoch 7/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8637 - loss: 0.2929 - val_accuracy: 0.8516 - val_loss: 0.3177
# Epoch 8/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8659 - loss: 0.2886 - val_accuracy: 0.8516 - val_loss: 0.3211
# Epoch 9/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8677 - loss: 0.2853 - val_accuracy: 0.8519 - val_loss: 0.3223
# Epoch 10/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8696 - loss: 0.2806 - val_accuracy: 0.8468 - val_loss: 0.3279
# Epoch 11/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8699 - loss: 0.2771 - val_accuracy: 0.8458 - val_loss: 0.3293
# Epoch 12/12
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8729 - loss: 0.2726 - val_accuracy: 0.8480 - val_loss: 0.3363
#
# Training with batch size = 128
# Epoch 1/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8383 - loss: 0.3460 - val_accuracy: 0.8477 - val_loss: 0.3216
# Epoch 2/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8530 - loss: 0.3146 - val_accuracy: 0.8523 - val_loss: 0.3173
# Epoch 3/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8567 - loss: 0.3095 - val_accuracy: 0.8513 - val_loss: 0.3175
# Epoch 4/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8582 - loss: 0.3066 - val_accuracy: 0.8511 - val_loss: 0.3166
# Epoch 5/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8583 - loss: 0.3049 - val_accuracy: 0.8511 - val_loss: 0.3149
# Epoch 6/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8596 - loss: 0.3019 - val_accuracy: 0.8522 - val_loss: 0.3145
# Epoch 7/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8609 - loss: 0.2994 - val_accuracy: 0.8463 - val_loss: 0.3250
# Epoch 8/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8638 - loss: 0.2965 - val_accuracy: 0.8498 - val_loss: 0.3154
# Epoch 9/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8656 - loss: 0.2931 - val_accuracy: 0.8477 - val_loss: 0.3228
# Epoch 10/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8655 - loss: 0.2905 - val_accuracy: 0.8516 - val_loss: 0.3161
# Epoch 11/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8661 - loss: 0.2881 - val_accuracy: 0.8520 - val_loss: 0.3164
# Epoch 12/12
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8670 - loss: 0.2863 - val_accuracy: 0.8468 - val_loss: 0.3200
#
# Training with batch size = 1024
# Epoch 1/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7415 - loss: 0.4954 - val_accuracy: 0.8305 - val_loss: 0.3677
# Epoch 2/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8390 - loss: 0.3450 - val_accuracy: 0.8445 - val_loss: 0.3346
# Epoch 3/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8504 - loss: 0.3236 - val_accuracy: 0.8494 - val_loss: 0.3239
# Epoch 4/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8539 - loss: 0.3162 - val_accuracy: 0.8486 - val_loss: 0.3219
# Epoch 5/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8548 - loss: 0.3128 - val_accuracy: 0.8513 - val_loss: 0.3189
# Epoch 6/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8567 - loss: 0.3103 - val_accuracy: 0.8501 - val_loss: 0.3175
# Epoch 7/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8564 - loss: 0.3083 - val_accuracy: 0.8499 - val_loss: 0.3169
# Epoch 8/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8573 - loss: 0.3065 - val_accuracy: 0.8496 - val_loss: 0.3170
# Epoch 9/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8581 - loss: 0.3053 - val_accuracy: 0.8508 - val_loss: 0.3166
# Epoch 10/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8593 - loss: 0.3038 - val_accuracy: 0.8502 - val_loss: 0.3172
# Epoch 11/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8598 - loss: 0.3024 - val_accuracy: 0.8496 - val_loss: 0.3174
# Epoch 12/12
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8598 - loss: 0.3019 - val_accuracy: 0.8499 - val_loss: 0.3166
#
# Part2 results saved to /content/adult_results/part2_batchsize_results.csv

# %% [markdown]
# ## Part 3 — Overfitting & Regularization
# Train a large model to provoke overfitting, then apply L2 and Dropout.

# %%
# Part3 experiments: Large model, L2, Dropout
large_hidden = [512,256,128]
results_reg = []

# Large model (no reg)
print('\nLarge model (no regularization)')
model_large = build_mlp(input_dim, hidden_layers=large_hidden, l2=0.0, dropout=0.0)
hist_large, tr_large, val_large, test_large = train_model(model_large, optimizer=keras.optimizers.Adam(1e-3), X_train=X_train_p, y_train=y_train, X_val=X_val_p, y_val=y_val, batch_size=128, epochs=25, verbose=1)
results_reg.append({'setting':'large_no_reg','train_acc':tr_large,'val_acc':val_large,'test_acc':test_large})
plt.figure(figsize=(6,4)); plt.plot(hist_large.history['accuracy'], label='train'); plt.plot(hist_large.history['val_accuracy'], label='val'); plt.title('Large no reg'); plt.legend(); plt.grid(True); plt.savefig('/content/adult_results/large_no_reg.png'); plt.close()

# L2 regularization
print('\nLarge model + L2')
model_l2 = build_mlp(input_dim, hidden_layers=large_hidden, l2=1e-4, dropout=0.0)
hist_l2, tr_l2, val_l2, test_l2 = train_model(model_l2, optimizer=keras.optimizers.Adam(1e-3), X_train=X_train_p, y_train=y_train, X_val=X_val_p, y_val=y_val, batch_size=128, epochs=25, verbose=1)
results_reg.append({'setting':'large_l2','train_acc':tr_l2,'val_acc':val_l2,'test_acc':test_l2})
plt.figure(figsize=(6,4)); plt.plot(hist_l2.history['accuracy'], label='train'); plt.plot(hist_l2.history['val_accuracy'], label='val'); plt.title('Large + L2'); plt.legend(); plt.grid(True); plt.savefig('/content/adult_results/large_l2.png'); plt.close()

# Dropout regularization
print('\nLarge model + Dropout')
model_do = build_mlp(input_dim, hidden_layers=large_hidden, l2=0.0, dropout=0.5)
hist_do, tr_do, val_do, test_do = train_model(model_do, optimizer=keras.optimizers.Adam(1e-3), X_train=X_train_p, y_train=y_train, X_val=X_val_p, y_val=y_val, batch_size=128, epochs=25, verbose=1)
results_reg.append({'setting':'large_dropout','train_acc':tr_do,'val_acc':val_do,'test_acc':test_do})
plt.figure(figsize=(6,4)); plt.plot(hist_do.history['accuracy'], label='train'); plt.plot(hist_do.history['val_accuracy'], label='val'); plt.title('Large + Dropout'); plt.legend(); plt.grid(True); plt.savefig('/content/adult_results/large_dropout.png'); plt.close()

pd.DataFrame(results_reg).to_csv('/content/adult_results/part3_regularization_results.csv', index=False)
print('\nPart3 results saved to /content/adult_results/part3_regularization_results.csv')
# Out:
# Large model (no regularization)
# Epoch 1/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8414 - loss: 0.3358 - val_accuracy: 0.8523 - val_loss: 0.3188
# Epoch 2/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8552 - loss: 0.3132 - val_accuracy: 0.8494 - val_loss: 0.3247
# Epoch 3/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8584 - loss: 0.3079 - val_accuracy: 0.8488 - val_loss: 0.3173
# Epoch 4/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8605 - loss: 0.3013 - val_accuracy: 0.8508 - val_loss: 0.3178
# Epoch 5/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8635 - loss: 0.2965 - val_accuracy: 0.8522 - val_loss: 0.3172
# Epoch 6/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8653 - loss: 0.2901 - val_accuracy: 0.8482 - val_loss: 0.3215
# Epoch 7/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8671 - loss: 0.2847 - val_accuracy: 0.8526 - val_loss: 0.3217
# Epoch 8/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8709 - loss: 0.2772 - val_accuracy: 0.8523 - val_loss: 0.3290
# Epoch 9/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8719 - loss: 0.2716 - val_accuracy: 0.8513 - val_loss: 0.3324
# Epoch 10/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8752 - loss: 0.2635 - val_accuracy: 0.8479 - val_loss: 0.3394
# Epoch 11/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8784 - loss: 0.2571 - val_accuracy: 0.8468 - val_loss: 0.3538
# Epoch 12/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8834 - loss: 0.2479 - val_accuracy: 0.8439 - val_loss: 0.3717
# Epoch 13/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8838 - loss: 0.2410 - val_accuracy: 0.8466 - val_loss: 0.3789
# Epoch 14/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8875 - loss: 0.2339 - val_accuracy: 0.8396 - val_loss: 0.3942
# Epoch 15/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8911 - loss: 0.2249 - val_accuracy: 0.8435 - val_loss: 0.4157
# Epoch 16/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8945 - loss: 0.2195 - val_accuracy: 0.8398 - val_loss: 0.4543
# Epoch 17/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8983 - loss: 0.2123 - val_accuracy: 0.8412 - val_loss: 0.4938
# Epoch 18/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8997 - loss: 0.2059 - val_accuracy: 0.8379 - val_loss: 0.5150
# Epoch 19/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9013 - loss: 0.2141 - val_accuracy: 0.8396 - val_loss: 0.5335
# Epoch 20/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9045 - loss: 0.1969 - val_accuracy: 0.8405 - val_loss: 0.5385
# Epoch 21/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9091 - loss: 0.1868 - val_accuracy: 0.8317 - val_loss: 0.5558
# Epoch 22/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9118 - loss: 0.1817 - val_accuracy: 0.8395 - val_loss: 0.5848
# Epoch 23/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9145 - loss: 0.1778 - val_accuracy: 0.8315 - val_loss: 0.6202
# Epoch 24/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9160 - loss: 0.1737 - val_accuracy: 0.8337 - val_loss: 0.6582
# Epoch 25/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9175 - loss: 0.1695 - val_accuracy: 0.8272 - val_loss: 0.6772
#
# Large model + L2
# Epoch 1/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8426 - loss: 0.3805 - val_accuracy: 0.8496 - val_loss: 0.3592
# Epoch 2/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8551 - loss: 0.3442 - val_accuracy: 0.8491 - val_loss: 0.3464
# Epoch 3/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8586 - loss: 0.3325 - val_accuracy: 0.8513 - val_loss: 0.3365
# Epoch 4/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8583 - loss: 0.3252 - val_accuracy: 0.8552 - val_loss: 0.3346
# Epoch 5/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8594 - loss: 0.3212 - val_accuracy: 0.8522 - val_loss: 0.3339
# Epoch 6/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8611 - loss: 0.3172 - val_accuracy: 0.8514 - val_loss: 0.3284
# Epoch 7/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8624 - loss: 0.3133 - val_accuracy: 0.8554 - val_loss: 0.3274
# Epoch 8/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8623 - loss: 0.3110 - val_accuracy: 0.8513 - val_loss: 0.3278
# Epoch 9/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8651 - loss: 0.3068 - val_accuracy: 0.8554 - val_loss: 0.3326
# Epoch 10/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8652 - loss: 0.3058 - val_accuracy: 0.8494 - val_loss: 0.3349
# Epoch 11/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8676 - loss: 0.3023 - val_accuracy: 0.8532 - val_loss: 0.3293
# Epoch 12/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8668 - loss: 0.2999 - val_accuracy: 0.8532 - val_loss: 0.3271
# Epoch 13/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8686 - loss: 0.2966 - val_accuracy: 0.8517 - val_loss: 0.3326
# Epoch 14/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8704 - loss: 0.2947 - val_accuracy: 0.8536 - val_loss: 0.3338
# Epoch 15/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8712 - loss: 0.2913 - val_accuracy: 0.8491 - val_loss: 0.3377
# Epoch 16/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8734 - loss: 0.2882 - val_accuracy: 0.8498 - val_loss: 0.3438
# Epoch 17/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8741 - loss: 0.2856 - val_accuracy: 0.8486 - val_loss: 0.3487
# Epoch 18/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8770 - loss: 0.2820 - val_accuracy: 0.8479 - val_loss: 0.3573
# Epoch 19/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8757 - loss: 0.2796 - val_accuracy: 0.8519 - val_loss: 0.3498
# Epoch 20/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8797 - loss: 0.2766 - val_accuracy: 0.8501 - val_loss: 0.3545
# Epoch 21/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8816 - loss: 0.2725 - val_accuracy: 0.8458 - val_loss: 0.3726
# Epoch 22/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8818 - loss: 0.2705 - val_accuracy: 0.8448 - val_loss: 0.3716
# Epoch 23/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8847 - loss: 0.2666 - val_accuracy: 0.8476 - val_loss: 0.3737
# Epoch 24/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8855 - loss: 0.2641 - val_accuracy: 0.8446 - val_loss: 0.3772
# Epoch 25/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8858 - loss: 0.2609 - val_accuracy: 0.8432 - val_loss: 0.3854
#
# Large model + Dropout
# Epoch 1/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8336 - loss: 0.3568 - val_accuracy: 0.8485 - val_loss: 0.3233
# Epoch 2/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8485 - loss: 0.3293 - val_accuracy: 0.8488 - val_loss: 0.3204
# Epoch 3/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8522 - loss: 0.3238 - val_accuracy: 0.8489 - val_loss: 0.3186
# Epoch 4/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8532 - loss: 0.3213 - val_accuracy: 0.8508 - val_loss: 0.3210
# Epoch 5/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8554 - loss: 0.3162 - val_accuracy: 0.8507 - val_loss: 0.3181
# Epoch 6/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8563 - loss: 0.3135 - val_accuracy: 0.8530 - val_loss: 0.3202
# Epoch 7/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8576 - loss: 0.3118 - val_accuracy: 0.8501 - val_loss: 0.3190
# Epoch 8/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8597 - loss: 0.3098 - val_accuracy: 0.8519 - val_loss: 0.3190
# Epoch 9/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8583 - loss: 0.3089 - val_accuracy: 0.8526 - val_loss: 0.3187
# Epoch 10/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8588 - loss: 0.3065 - val_accuracy: 0.8516 - val_loss: 0.3172
# Epoch 11/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8611 - loss: 0.3054 - val_accuracy: 0.8536 - val_loss: 0.3202
# Epoch 12/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8610 - loss: 0.3043 - val_accuracy: 0.8510 - val_loss: 0.3172
# Epoch 13/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8615 - loss: 0.3034 - val_accuracy: 0.8495 - val_loss: 0.3185
# Epoch 14/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8631 - loss: 0.2992 - val_accuracy: 0.8510 - val_loss: 0.3176
# Epoch 15/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8642 - loss: 0.2970 - val_accuracy: 0.8526 - val_loss: 0.3180
# Epoch 16/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8630 - loss: 0.2947 - val_accuracy: 0.8505 - val_loss: 0.3183
# Epoch 17/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8640 - loss: 0.2913 - val_accuracy: 0.8511 - val_loss: 0.3200
# Epoch 18/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8655 - loss: 0.2920 - val_accuracy: 0.8516 - val_loss: 0.3199
# Epoch 19/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8662 - loss: 0.2871 - val_accuracy: 0.8510 - val_loss: 0.3264
# Epoch 20/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8646 - loss: 0.2894 - val_accuracy: 0.8498 - val_loss: 0.3220
# Epoch 21/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8656 - loss: 0.2871 - val_accuracy: 0.8536 - val_loss: 0.3242
# Epoch 22/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8684 - loss: 0.2842 - val_accuracy: 0.8494 - val_loss: 0.3257
# Epoch 23/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8677 - loss: 0.2844 - val_accuracy: 0.8519 - val_loss: 0.3257
# Epoch 24/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8698 - loss: 0.2807 - val_accuracy: 0.8501 - val_loss: 0.3276
# Epoch 25/25
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8711 - loss: 0.2802 - val_accuracy: 0.8501 - val_loss: 0.3301
#
# Part3 results saved to /content/adult_results/part3_regularization_results.csv

# %% [markdown]
# ### Part 4: Early Stopping

# %%
# Part4: Early stopping comparison
# Without early stopping (long)
print('\nLong training without early stopping')
model_long = build_mlp(input_dim, hidden_layers=[256,128,64], l2=0.0, dropout=0.0)
hist_long, tr_long, val_long, test_long = train_model(model_long, optimizer=keras.optimizers.Adam(1e-3), X_train=X_train_p, y_train=y_train, X_val=X_val_p, y_val=y_val, batch_size=128, epochs=80, verbose=1)
plt.figure(figsize=(6,4)); plt.plot(hist_long.history['accuracy'], label='train'); plt.plot(hist_long.history['val_accuracy'], label='val'); plt.title('Long training no ES'); plt.legend(); plt.grid(True); plt.savefig('/content/adult_results/long_no_es.png'); plt.close()

# With early stopping
print('\nTraining with Early Stopping (monitor val_loss)')
model_es = build_mlp(input_dim, hidden_layers=[256,128,64], l2=0.0, dropout=0.0)
hist_es, tr_es, val_es, test_es = train_model(model_es, optimizer=keras.optimizers.Adam(1e-3), X_train=X_train_p, y_train=y_train, X_val=X_val_p, y_val=y_val, batch_size=128, epochs=200, use_early_stopping=True, verbose=1)
plt.figure(figsize=(6,4)); plt.plot(hist_es.history['accuracy'], label='train'); plt.plot(hist_es.history['val_accuracy'], label='val'); plt.title('Early stopping'); plt.legend(); plt.grid(True); plt.savefig('/content/adult_results/early_stopping.png'); plt.close()

pd.DataFrame([{'setting':'long_no_es','train_acc':tr_long,'val_acc':val_long,'test_acc':test_long},
              {'setting':'with_es','train_acc':tr_es,'val_acc':val_es,'test_acc':test_es}]).to_csv('/content/adult_results/part4_earlystopping_results.csv', index=False)
print('\nPart4 results saved to /content/adult_results/part4_earlystopping_results.csv')
# Out:
# Long training without early stopping
# Epoch 1/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8389 - loss: 0.3403 - val_accuracy: 0.8516 - val_loss: 0.3188
# Epoch 2/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8533 - loss: 0.3129 - val_accuracy: 0.8502 - val_loss: 0.3169
# Epoch 3/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8575 - loss: 0.3071 - val_accuracy: 0.8513 - val_loss: 0.3159
# Epoch 4/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8609 - loss: 0.3018 - val_accuracy: 0.8513 - val_loss: 0.3149
# Epoch 5/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8623 - loss: 0.2985 - val_accuracy: 0.8529 - val_loss: 0.3142
# Epoch 6/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8634 - loss: 0.2939 - val_accuracy: 0.8507 - val_loss: 0.3179
# Epoch 7/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8633 - loss: 0.2905 - val_accuracy: 0.8538 - val_loss: 0.3147
# Epoch 8/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8675 - loss: 0.2837 - val_accuracy: 0.8541 - val_loss: 0.3183
# Epoch 9/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8686 - loss: 0.2801 - val_accuracy: 0.8496 - val_loss: 0.3214
# Epoch 10/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8723 - loss: 0.2743 - val_accuracy: 0.8507 - val_loss: 0.3230
# Epoch 11/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8740 - loss: 0.2690 - val_accuracy: 0.8551 - val_loss: 0.3267
# Epoch 12/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8769 - loss: 0.2621 - val_accuracy: 0.8523 - val_loss: 0.3350
# Epoch 13/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8790 - loss: 0.2577 - val_accuracy: 0.8446 - val_loss: 0.3490
# Epoch 14/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8814 - loss: 0.2518 - val_accuracy: 0.8445 - val_loss: 0.3490
# Epoch 15/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8842 - loss: 0.2452 - val_accuracy: 0.8467 - val_loss: 0.3608
# Epoch 16/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8875 - loss: 0.2392 - val_accuracy: 0.8386 - val_loss: 0.3706
# Epoch 17/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8900 - loss: 0.2332 - val_accuracy: 0.8438 - val_loss: 0.3821
# Epoch 18/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8907 - loss: 0.2279 - val_accuracy: 0.8352 - val_loss: 0.3913
# Epoch 19/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8912 - loss: 0.2249 - val_accuracy: 0.8349 - val_loss: 0.4279
# Epoch 20/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8963 - loss: 0.2168 - val_accuracy: 0.8438 - val_loss: 0.4315
# Epoch 21/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8993 - loss: 0.2124 - val_accuracy: 0.8355 - val_loss: 0.4184
# Epoch 22/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9009 - loss: 0.2082 - val_accuracy: 0.8423 - val_loss: 0.4357
# Epoch 23/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9055 - loss: 0.2007 - val_accuracy: 0.8349 - val_loss: 0.4634
# Epoch 24/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9067 - loss: 0.1959 - val_accuracy: 0.8373 - val_loss: 0.4665
# Epoch 25/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9079 - loss: 0.1920 - val_accuracy: 0.8362 - val_loss: 0.4830
# Epoch 26/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9098 - loss: 0.1894 - val_accuracy: 0.8409 - val_loss: 0.5158
# Epoch 27/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9120 - loss: 0.1862 - val_accuracy: 0.8321 - val_loss: 0.5240
# Epoch 28/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9132 - loss: 0.1834 - val_accuracy: 0.8331 - val_loss: 0.5469
# Epoch 29/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9149 - loss: 0.1766 - val_accuracy: 0.8272 - val_loss: 0.5767
# Epoch 30/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9181 - loss: 0.1722 - val_accuracy: 0.8377 - val_loss: 0.5716
# Epoch 31/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9205 - loss: 0.1691 - val_accuracy: 0.8334 - val_loss: 0.5929
# Epoch 32/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9205 - loss: 0.1666 - val_accuracy: 0.8299 - val_loss: 0.5909
# Epoch 33/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9217 - loss: 0.1656 - val_accuracy: 0.8325 - val_loss: 0.6242
# Epoch 34/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9233 - loss: 0.1600 - val_accuracy: 0.8317 - val_loss: 0.6519
# Epoch 35/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9256 - loss: 0.1583 - val_accuracy: 0.8209 - val_loss: 0.6538
# Epoch 36/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9237 - loss: 0.1596 - val_accuracy: 0.8272 - val_loss: 0.6797
# Epoch 37/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9262 - loss: 0.1546 - val_accuracy: 0.8200 - val_loss: 0.6894
# Epoch 38/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9271 - loss: 0.1528 - val_accuracy: 0.8289 - val_loss: 0.7264
# Epoch 39/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9289 - loss: 0.1498 - val_accuracy: 0.8314 - val_loss: 0.7297
# Epoch 40/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9299 - loss: 0.1479 - val_accuracy: 0.8290 - val_loss: 0.7925
# Epoch 41/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9294 - loss: 0.1475 - val_accuracy: 0.8330 - val_loss: 0.7621
# Epoch 42/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9315 - loss: 0.1463 - val_accuracy: 0.8268 - val_loss: 0.7398
# Epoch 43/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9313 - loss: 0.1432 - val_accuracy: 0.8296 - val_loss: 0.8027
# Epoch 44/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9323 - loss: 0.1420 - val_accuracy: 0.8259 - val_loss: 0.7611
# Epoch 45/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9330 - loss: 0.1382 - val_accuracy: 0.8230 - val_loss: 0.7961
# Epoch 46/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9351 - loss: 0.1375 - val_accuracy: 0.8280 - val_loss: 0.8435
# Epoch 47/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9366 - loss: 0.1335 - val_accuracy: 0.8255 - val_loss: 0.8347
# Epoch 48/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9359 - loss: 0.1330 - val_accuracy: 0.8233 - val_loss: 0.8437
# Epoch 49/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9351 - loss: 0.1332 - val_accuracy: 0.8280 - val_loss: 0.9132
# Epoch 50/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9381 - loss: 0.1306 - val_accuracy: 0.8286 - val_loss: 0.8495
# Epoch 51/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9397 - loss: 0.1277 - val_accuracy: 0.8243 - val_loss: 0.8818
# Epoch 52/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9361 - loss: 0.1366 - val_accuracy: 0.8267 - val_loss: 0.8625
# Epoch 53/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9381 - loss: 0.1297 - val_accuracy: 0.8247 - val_loss: 0.9008
# Epoch 54/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9408 - loss: 0.1246 - val_accuracy: 0.8200 - val_loss: 0.8912
# Epoch 55/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9412 - loss: 0.1247 - val_accuracy: 0.8205 - val_loss: 0.9354
# Epoch 56/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9429 - loss: 0.1211 - val_accuracy: 0.8236 - val_loss: 0.9237
# Epoch 57/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9415 - loss: 0.1203 - val_accuracy: 0.8181 - val_loss: 0.9845
# Epoch 58/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9409 - loss: 0.1268 - val_accuracy: 0.8262 - val_loss: 0.9298
# Epoch 59/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9427 - loss: 0.1253 - val_accuracy: 0.8208 - val_loss: 0.9183
# Epoch 60/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9449 - loss: 0.1175 - val_accuracy: 0.8228 - val_loss: 0.9615
# Epoch 61/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9446 - loss: 0.1190 - val_accuracy: 0.8231 - val_loss: 0.9697
# Epoch 62/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9448 - loss: 0.1171 - val_accuracy: 0.8230 - val_loss: 0.9849
# Epoch 63/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9453 - loss: 0.1171 - val_accuracy: 0.8197 - val_loss: 0.9955
# Epoch 64/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9449 - loss: 0.1162 - val_accuracy: 0.8177 - val_loss: 1.0177
# Epoch 65/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9471 - loss: 0.1130 - val_accuracy: 0.8224 - val_loss: 1.0259
# Epoch 66/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9450 - loss: 0.1178 - val_accuracy: 0.8212 - val_loss: 1.0159
# Epoch 67/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9473 - loss: 0.1096 - val_accuracy: 0.8190 - val_loss: 1.0720
# Epoch 68/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9476 - loss: 0.1125 - val_accuracy: 0.8218 - val_loss: 1.0532
# Epoch 69/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9459 - loss: 0.1153 - val_accuracy: 0.8188 - val_loss: 1.0347
# Epoch 70/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9497 - loss: 0.1066 - val_accuracy: 0.8187 - val_loss: 1.0703
# Epoch 71/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9498 - loss: 0.1061 - val_accuracy: 0.8283 - val_loss: 1.1446
# Epoch 72/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9509 - loss: 0.1039 - val_accuracy: 0.8196 - val_loss: 1.1151
# Epoch 73/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9509 - loss: 0.1062 - val_accuracy: 0.8246 - val_loss: 1.1258
# Epoch 74/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9501 - loss: 0.1079 - val_accuracy: 0.8188 - val_loss: 1.1096
# Epoch 75/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9513 - loss: 0.1070 - val_accuracy: 0.8230 - val_loss: 1.1537
# Epoch 76/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9505 - loss: 0.1067 - val_accuracy: 0.8209 - val_loss: 1.1643
# Epoch 77/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9510 - loss: 0.1030 - val_accuracy: 0.8222 - val_loss: 1.1444
# Epoch 78/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9531 - loss: 0.0996 - val_accuracy: 0.8253 - val_loss: 1.1994
# Epoch 79/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9525 - loss: 0.1015 - val_accuracy: 0.8159 - val_loss: 1.2789
# Epoch 80/80
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9504 - loss: 0.1082 - val_accuracy: 0.8219 - val_loss: 1.2099
#
# Training with Early Stopping (monitor val_loss)
# Epoch 1/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8409 - loss: 0.3382 - val_accuracy: 0.8505 - val_loss: 0.3197
# Epoch 2/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8540 - loss: 0.3139 - val_accuracy: 0.8488 - val_loss: 0.3205
# Epoch 3/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8562 - loss: 0.3092 - val_accuracy: 0.8492 - val_loss: 0.3221
# Epoch 4/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8589 - loss: 0.3032 - val_accuracy: 0.8535 - val_loss: 0.3162
# Epoch 5/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8634 - loss: 0.2979 - val_accuracy: 0.8539 - val_loss: 0.3184
# Epoch 6/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8631 - loss: 0.2944 - val_accuracy: 0.8547 - val_loss: 0.3142
# Epoch 7/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8644 - loss: 0.2897 - val_accuracy: 0.8526 - val_loss: 0.3185
# Epoch 8/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8677 - loss: 0.2847 - val_accuracy: 0.8514 - val_loss: 0.3260
# Epoch 9/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8703 - loss: 0.2781 - val_accuracy: 0.8488 - val_loss: 0.3268
# Epoch 10/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8730 - loss: 0.2728 - val_accuracy: 0.8489 - val_loss: 0.3260
# Epoch 11/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8742 - loss: 0.2678 - val_accuracy: 0.8471 - val_loss: 0.3347
# Epoch 12/200
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8778 - loss: 0.2613 - val_accuracy: 0.8466 - val_loss: 0.3468
#
# Part4 results saved to /content/adult_results/part4_earlystopping_results.csv

# %% [markdown]
# ## Part 5 — Reflection
# Summarize results and recommended choices. The notebook also saves CSVs and PNGs under `/content/adult_results`.

# %%
# Final summary table (combine saved CSVs if exist)
import pandas as pd, os, glob
files = glob.glob('/content/adult_results/*.csv')
summary = []
for f in files:
    try:
        df = pd.read_csv(f)
        df['source_file'] = os.path.basename(f)
        summary.append(df)
    except Exception as e:
        print('skip', f, e)

if summary:
    big = pd.concat(summary, ignore_index=True, sort=False)
    big.to_csv('/content/adult_results/combined_results.csv', index=False)
    print('Combined results saved to /content/adult_results/combined_results.csv')
else:
    print('No CSV results found yet. Run the experiment cells first.')

print('\nAll output files (plots + CSVs) will be in /content/adult_results. Download as a zip if needed.')
# Out:
# Combined results saved to /content/adult_results/combined_results.csv
#
# All output files (plots + CSVs) will be in /content/adult_results. Download as a zip if needed.

# %% [markdown]
# Thank you _ Abdelrahman Elsaeed
